# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Tensor 1D Practice

numpy_=np.random.randint(0,5,10)
print(numpy_,"\tData type of this variable is",type(numpy_))
print("\n")
tensor_=torch.from_numpy(numpy_)

print(tensor_,"\tData type of variable in the tensor is",tensor_.dtype)
print(tensor_,"\tType of the Tensor is",tensor_.type())

l=numpy_.tolist()
print("\n")
print(l,"\tData type of this variable is",type(l))

tensor_=torch.tensor(l)
print("\n")
print(tensor_,"\tData type of variable in the tensor is",tensor_.dtype)
print(tensor_,"\tType of the Tensor is",tensor_.type())

#Converting Tensor to different TensorTypes-

fl_tensor_=tensor_.type(torch.FloatTensor)
print("\n")
print(fl_tensor_,"Data type of variable in the tensor is",fl_tensor_.dtype)
print(fl_tensor_,"Type of tensor is",fl_tensor_.type())

print("\n")
db_tensor_=tensor_.type(torch.DoubleTensor)
print(db_tensor_,"Data type of variable in the tensor is",db_tensor_.dtype)
print(db_tensor_,"Type of tensor is",db_tensor_.type())

print("\n")
lg_tensor_=tensor_.type(torch.LongTensor)
print(lg_tensor_,"Data type of variable in the tensor is",lg_tensor_.dtype)
print(lg_tensor_,"Type of tensor is",lg_tensor_.type())


#Size of the Tensor
print("\nThe size of the tensor: ",tensor_.size())
print("The dimension of the tensor: ",tensor_.ndimension())

#Using the view(row,col) function
print("\n")
tensor_vert=tensor_.view(-1,1)
print(tensor_vert)
# Out:
# [4 0 3 0 2 4 1 4 3 1] 	Data type of this variable is <class 'numpy.ndarray'>
#
#
# tensor([4, 0, 3, 0, 2, 4, 1, 4, 3, 1]) 	Data type of variable in the tensor is torch.int64
# tensor([4, 0, 3, 0, 2, 4, 1, 4, 3, 1]) 	Type of the Tensor is torch.LongTensor
#
#
# [4, 0, 3, 0, 2, 4, 1, 4, 3, 1] 	Data type of this variable is <class 'list'>
#
#
# tensor([4, 0, 3, 0, 2, 4, 1, 4, 3, 1]) 	Data type of variable in the tensor is torch.int64
# tensor([4, 0, 3, 0, 2, 4, 1, 4, 3, 1]) 	Type of the Tensor is torch.LongTensor
#
#
# tensor([4., 0., 3., 0., 2., 4., 1., 4., 3., 1.]) Data type of variable in the tensor is torch.float32
# tensor([4., 0., 3., 0., 2., 4., 1., 4., 3., 1.]) Type of tensor is torch.FloatTensor
#
#
# tensor([4., 0., 3., 0., 2., 4., 1., 4., 3., 1.], dtype=torch.float64) Data type of variable in the tensor is torch.float64
# tensor([4., 0., 3., 0., 2., 4., 1., 4., 3., 1.], dtype=torch.float64) Type of tensor is torch.DoubleTensor
#
#
# ...

# %%
# Practice: Change the values on index 3, 4, 7 to 0
print("Changing values at the index 3, 4, and 7 to 0")
practice_tensor = torch.tensor([2, 7, 3, 4, 6, 2, 3, 1, 2])
print(practice_tensor)
selected_index=[3,4,7]
practice_tensor[selected_index]=torch.tensor([0])
print(practice_tensor)
print("\n")

# Practice: mean(), std(), max(), min():
print("Practicing mean, std, max and min methods of the tensor")
x=np.random.randint(0,10,15)
tensor_=torch.from_numpy(x)

tensor_=tensor_.type(torch.FloatTensor)

print("The tensor is as follow:")
print(tensor_.type(torch.LongTensor))
print("\n")

print("Mean               : ",torch.mean(tensor_))
print("Standard Deviation : ",torch.std(tensor_))
print("Maximum Value      : ",torch.max(tensor_))
print("Minimum Value      : ",torch.min(tensor_))
print("\n")

# Practice: linspace- returning sine values and plotting graph for the same
print("Using linspace to define points, sin function to get the value and plot function to plot sin(x)")
x=torch.linspace(0,2*np.pi,100)
y=torch.sin(x)

plt.plot(x,y)
plt.show()
print("\n")

#Basic Operations using Tensor

u=torch.from_numpy(np.random.randint(1,6,5))
v=torch.from_numpy(np.random.randint(6,11,5))
print("Sum of two 1D tensors:")
print("u   = ",u)
print("v   = ",v)
print("u+v = ",u+v)

print("\nDifference between two 1D tensors:")
print("u   = ",u)
print("v   = ",v)
print("u-v = ",u-v)

print("\nMultiplication of two 1D tensors:")
print("u   = ",u)
print("v   = ",v)
print("u*v = ",u*v)

print("\nDot Product of two 1D tensors:")
print("u   = ",u)
print("v   = ",v)
print("dot(u,v) = ",torch.dot(u,v))

print("\nAdding Scalar to the two 1D tensors:")
print("u   = ",u)
print("v   = ",v)
print("u+10 = ",u+10)
print("v+20 = ",v+20)
print("\n")
# Out:
# Changing values at the index 3, 4, and 7 to 0
# tensor([2, 7, 3, 4, 6, 2, 3, 1, 2])
# tensor([2, 7, 3, 0, 0, 2, 3, 0, 2])
#
#
# Practicing mean, std, max and min methods of the tensor
# The tensor is as follow:
# tensor([0, 2, 8, 5, 2, 6, 6, 9, 5, 4, 6, 2, 3, 0, 9])
#
#
# Mean               :  tensor(4.4667)
# Standard Deviation :  tensor(2.9488)
# Maximum Value      :  tensor(9.)
# Minimum Value      :  tensor(0.)
#
#
# Using linspace to define points, sin function to get the value and plot function to plot sin(x)
# Sum of two 1D tensors:
# u   =  tensor([5, 3, 4, 1, 3])
# v   =  tensor([ 9, 10,  6,  6,  9])
# u+v =  tensor([14, 13, 10,  7, 12])
#
# Difference between two 1D tensors:
# u   =  tensor([5, 3, 4, 1, 3])
# v   =  tensor([ 9, 10,  6,  6,  9])
# u-v =  tensor([-4, -7, -2, -5, -6])
#
# Multiplication of two 1D tensors:
# u   =  tensor([5, 3, 4, 1, 3])
# v   =  tensor([ 9, 10,  6,  6,  9])
# u*v =  tensor([45, 30, 24,  6, 27])
#
# Dot Product of two 1D tensors:
# ...

# %%
                                             # 2-Dimensional Tensors

# %%
numpy_arr_1=[[np.random.randint(0,10) for i in range(3)] for j in range(3)]
tensor_2d_1=torch.tensor(numpy_arr_1)
print("Matrix 1:")
print(tensor_2d_1.view(3,3))

numpy_arr_2=[[np.random.randint(0,10) for i in range(3)] for j in range(3)]
tensor_2d_2=torch.tensor(numpy_arr_2)
print("Matrix 2:")
print(tensor_2d_2.view(3,3))
print("\n")
#Matrix Multiplication
tensor_2d_mm=torch.mm(tensor_2d_1,tensor_2d_2)
print("After Matrix Multiplication:")
print(tensor_2d_mm.view(3,3))

#Hadamard Multiplication
print("\nAfter Normal Multiplication:")
tensor_2d_np=tensor_2d_1*tensor_2d_2
print(tensor_2d_np)

#Matrix Addition and Subtraction
print("\nAfter Addition:")
tensor_2d_add=tensor_2d_1+tensor_2d_2
print(tensor_2d_add)

print("\nAfter Subtraction:")
tensor_2d_sub=tensor_2d_1-tensor_2d_2
print(tensor_2d_sub)
# Out:
# Matrix 1:
# tensor([[6, 9, 8],
#         [3, 8, 9],
#         [6, 5, 6]])
# Matrix 2:
# tensor([[2, 0, 7],
#         [9, 9, 0],
#         [6, 0, 7]])
#
#
# After Matrix Multiplication:
# tensor([[141,  81,  98],
#         [132,  72,  84],
#         [ 93,  45,  84]])
#
# After Normal Multiplication:
# tensor([[12,  0, 56],
#         [27, 72,  0],
#         [36,  0, 42]])
#
# After Addition:
# tensor([[ 8,  9, 15],
#         [12, 17,  9],
#         [12,  5, 13]])
#
# After Subtraction:
# tensor([[ 4,  9,  1],
#         [-6, -1,  9],
#         [ 0,  5, -1]])

# %%
                                        # Derivatives and Partial Derivatives

# %%
plt.figure(figsize=(8,8))

x=torch.linspace(-10,10,100,requires_grad=True)
y=x**2
plt.plot(x.detach().numpy(),y.detach().numpy(),label="function")

y=torch.sum(x**2)
y.backward()
z=x.grad

z=x.grad.detach().numpy()
x=x.detach().numpy()
y=y.detach().numpy()



plt.plot(x,z,label="derivative")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))

x=torch.linspace(0,2*np.pi,100,requires_grad=True)
y=torch.sin(x)*torch.cos(x)
plt.plot(x.detach().numpy(),y.detach().numpy(),label="f(x)=sin(x).cos(x)")

y=torch.sum(torch.sin(x)*torch.cos(x))
y.backward()

plt.plot(x.detach().numpy(),x.grad.detach().numpy(),label="f`(x)=d(f(x)/dx)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))

x=torch.linspace(-10,10,100,requires_grad=True)
y=x**3+x**2+x+1
plt.plot(x.detach().numpy(),y.detach().numpy(),label="f(x)")

y=torch.sum(x**3+x**2+x+1)
y.backward()

plt.plot(x.detach().numpy(),x.grad.detach().numpy(),label="d(f(x))/dx")

plt.legend()
plt.show()

# %%
x=torch.linspace(0,5,1000, requires_grad=True)
y=x*torch.log(x)
plt.plot(x.detach().numpy(),y.detach().numpy(),label="f(x)=x*log(x)")

y=torch.sum(x*torch.log(x))
y.backward()

plt.plot(x.detach().numpy(),x.grad.detach().numpy(),label="df(x)/dx")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
x=torch.linspace(-5,5,100,requires_grad=True)
y=x**x

plt.plot(x.detach().numpy(),y.detach().numpy(),label="f(x)")
y=torch.sum(x**3)
y.backward()

plt.plot(x.detach().numpy(),x.grad.detach().numpy(),label="df(x)/dx")
plt.show()

# %%
# Simple Dataset Object

# %%
import torch
from torch.utils.data import Dataset
torch.manual_seed(1)

# %%
class toy_set(Dataset):
    
    # Constructor with defult values 
    def __init__(self, length = 100, transform = None):
        self.len = length
        self.x = 2 * torch.ones(length, 2)
        self.y = torch.ones(length, 1)
        self.transform = transform
     
    # Getter
    def __getitem__(self, index):
        sample = self.x[index], self.y[index]
        if self.transform:
            sample = self.transform(sample)     
        return sample
    
    # Get Length
    def __len__(self):
        return self.len

# %%
our_dataset=toy_set()
print("Our toy_set object: ", our_dataset)
print("Value on index 0 of our toy_set object: ", our_dataset[0])
print("Our toy_set length: ", len(our_dataset))
# Out:
# Our toy_set object:  <__main__.toy_set object at 0x1323da110>
# Value on index 0 of our toy_set object:  (tensor([2., 2.]), tensor([1.]))
# Our toy_set length:  100

# %%
# Print first 3 objects and then assign them to dataset

for i in range(3):
    x,y=our_dataset[i]
    
print("First three object in our_dataset:\n")
print(our_dataset[0])
print(our_dataset[1])
print(our_dataset[2])
# Out:
# First three object in our_dataset:
#
# (tensor([2., 2.]), tensor([1.]))
# (tensor([2., 2.]), tensor([1.]))
# (tensor([2., 2.]), tensor([1.]))

# %%
# Create tranform class add_mult

class add_mult(object):
    
    # Constructor
    def __init__(self, addx = 1, muly = 2):
        self.addx = addx
        self.muly = muly
    
    # Executor
    def __call__(self, sample):
        x = sample[0]
        y = sample[1]
        x = x + self.addx
        y = y * self.muly
        sample = x, y
        return sample
    
# Create an add_mult transform object, and an toy_set object

a_m = add_mult()
data_set = toy_set()

# Use loop to print out first 10 elements in dataset
print("\n")
for i in range(10):
    x, y = data_set[i]
    print('Index: ', i, '\tOriginal x    : ', x, '\tOriginal y    : ', y)
    x_, y_ = a_m(data_set[i])
    print('Index: ', i, '\tTransformed x : ', x_, '\tTransformed y : ', y_)
print("\n")
# Out:
# Index:  0 	Original x    :  tensor([2., 2.]) 	Original y    :  tensor([1.])
# Index:  0 	Transformed x :  tensor([3., 3.]) 	Transformed y :  tensor([2.])
# Index:  1 	Original x    :  tensor([2., 2.]) 	Original y    :  tensor([1.])
# Index:  1 	Transformed x :  tensor([3., 3.]) 	Transformed y :  tensor([2.])
# Index:  2 	Original x    :  tensor([2., 2.]) 	Original y    :  tensor([1.])
# Index:  2 	Transformed x :  tensor([3., 3.]) 	Transformed y :  tensor([2.])
# Index:  3 	Original x    :  tensor([2., 2.]) 	Original y    :  tensor([1.])
# Index:  3 	Transformed x :  tensor([3., 3.]) 	Transformed y :  tensor([2.])
# Index:  4 	Original x    :  tensor([2., 2.]) 	Original y    :  tensor([1.])
# Index:  4 	Transformed x :  tensor([3., 3.]) 	Transformed y :  tensor([2.])
# Index:  5 	Original x    :  tensor([2., 2.]) 	Original y    :  tensor([1.])
# Index:  5 	Transformed x :  tensor([3., 3.]) 	Transformed y :  tensor([2.])
# ...

# %%
# These are the libraries will be used for this lab.

import torch 
import matplotlib.pylab as plt
import numpy as np
import torchvision.transforms as transforms
import torchvision.datasets as dsets
torch.manual_seed(0)

# Show data by diagram

def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.show()

    
# Import the prebuilt dataset into variable dataset

dataset = dsets.MNIST(
    root = './data', 
    train = False, 
    download = True, 
    transform = transforms.ToTensor()
)

# Examine whether the elements in dataset MNIST are tuples, and what is in the tuple?

print("Type of the first element: ", type(dataset[0]))
print("The length of the tuple: ", len(dataset[0]))
print("The shape of the first element in the tuple: ", dataset[0][0].shape)
print("The type of the first element in the tuple", type(dataset[0][0]))
print("The type of the second element in the tuple: ", type(dataset[0][1]))


# Plot the first element in the dataset

show_data(dataset[1])
# Out:
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# ...
# 9920512it [00:00, 10923313.58it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# 32768it [00:00, 504590.89it/s]
#   1%|          | 16384/1648877 [00:00<00:11, 136885.12it/s]
# ...
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# ...
# 1654784it [00:00, 6274208.21it/s]
# 8192it [00:00, 165114.05it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# Type of the first element:  <class 'tuple'>
# The length of the tuple:  2
# The shape of the first element in the tuple:  torch.Size([1, 28, 28])
# The type of the first element in the tuple <class 'torch.Tensor'>
# The type of the second element in the tuple:  <class 'int'>

# %%
# Combine two transforms: crop and convert to tensor. Apply the compose to MNIST dataset

croptensor_data_transform = transforms.Compose([transforms.CenterCrop(20), transforms.ToTensor()])
dataset = dsets.MNIST(root = './data', train = False, download = True, transform = croptensor_data_transform)
print("The shape of the first element in the first tuple: ", dataset[0][0].shape)
#Plot the image
show_data(dataset[1],shape = (20, 20))



# Horizontally flip the image, and then convert it to a tensor

fliptensor_data_transform=transforms.Compose([transforms.RandomHorizontalFlip(p=1),transforms.ToTensor()])
dataset= dsets.MNIST(root='./data', train=False, download=True, transform=fliptensor_data_transform)
print("The shape of the first element in the first tuple: ",dataset[0][0].shape)
#Plot the image with shape (20,20)
show_data(dataset[1])



#Vertcally flip the image, and then convert it to a tensor

verticaltensor_data_transform=transforms.Compose([transforms.RandomVerticalFlip(p=1), transforms.ToTensor()])
dataset=dsets.MNIST(root="./data",train=False, download=True, transform=verticaltensor_data_transform)
print("The shape of the first element in the first tuple: ",dataset[0][0].shape)
#Plot the image
show_data(dataset[1])



# First Horizontally and then Vertcally flip the image, and then convert it to a tensor
verthorizTensor_data_transform=transforms.Compose(
    [transforms.RandomHorizontalFlip(p=1), transforms.RandomVerticalFlip(p=1), transforms.ToTensor()])
dataset=dsets.MNIST(root="./data", train=False, download=True, transform=verthorizTensor_data_transform)
print("The shape of the first element in the first tuple: ",dataset[0][0].shape)
#Plot the image
show_data(dataset[1])
# Out:
# The shape of the first element in the first tuple:  torch.Size([1, 20, 20])
# The shape of the first element in the first tuple:  torch.Size([1, 28, 28])
# The shape of the first element in the first tuple:  torch.Size([1, 28, 28])
# The shape of the first element in the first tuple:  torch.Size([1, 28, 28])
